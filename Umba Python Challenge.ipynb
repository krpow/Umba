# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm

# %%
logins = pd.read_csv("weekly_logins.csv")

# %%
logins = logins.sort_values(by = 'Weekly Logins', ascending = False)
logins.head()
# Out:
#             User Name Slack Integration    Most Used Page Had Free Trial  \
# 1267  Charlie Hurrell                No  /tool/storyboard            Yes
# 341        Paul Krupp               Yes  /tool/storyboard            Yes
# 452     Brigid Watson                No  /tool/storyboard            Yes
# 578     George Palmer               Yes  /tool/storyboard            Yes
# 1202   Claudia Wilson                No  /tool/storyboard            Yes
#
#       User MRR  Weekly Logins Company Name           Industry   Company Size  \
# 1267        39             17         Visa         Technology          >$10B
# 341        169             17  Lucky Brand  Consumer Products  $100M - $500M
# 452         39             17       Siemon      Manufacturing  $100M - $500M
# 578         39             17       SpaceX         Technology     $1B - $10B
# 1202       169             17         Visa         Technology          >$10B
#
#      Territory Sales Call in Trial Zendesk Integration Salesforce Integration  \
# 1267      West                  No                 Yes                    Yes
# 341       West                  No                  No                     No
# 452    Midwest                  No                  No                    Yes
# 578       West                  No                 Yes                     No
# 1202      West                  No                 Yes                    Yes
#
#      Gmail Integration Most common referrer   Most common IP  \
# 1267               Yes     /mail.google.com  198.199.120.102
# 341                Yes           /slack.com   138.197.222.35
# 452                Yes           hotels.com   192.200.200.99
# 578                 No               /quora    174.138.54.49
# 1202               Yes        /facebook.com  198.199.120.102
#
#       Sales Touches to Close Used Admin Panel Has Issued Support Request
# 1267                       6               No                        Yes
# 341                        4              Yes                         No
# 452                       14              Yes                        Yes
# 578                        9               No                         No
# 1202                       5              Yes                         No

# %%
logins1 = logins[['Weekly Logins','Had Free Trial']]
#logins1['Yes'] = logins[]
logins1.groupby('Weekly Logins')['Had Free Trial'].value_counts().plot(kind = 'bar')
# Out:
# <AxesSubplot:xlabel='Weekly Logins,Had Free Trial'>

# %% [markdown]
# We can see that those who had a free trial were more likely to have the most weekly logins.

# %%
logins2 = logins[logins['Weekly Logins'] > 13]
logins2['Industry'].value_counts().plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %%
logins2['Company Size'].value_counts().plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# Looking at just the data on people who had more than 13 weekly logins, we can see that most of these people worked in the technology industry. Most of these people also work at large companies of size 100M - 500M.

# %%
logins3 = logins.replace({'Zendesk Integration': {'Yes': 1, 
                                'No': 0}})
logins3 = logins3.replace({'Had Free Trial': {'Yes': 1, 
                                'No': 0}})
logins3 = logins3.replace({'Sales Call in Trial': {'Yes': 1, 
                                'No': 0}})
logins3 = logins3.replace({'Salesforce Integration': {'Yes': 1, 
                                'No': 0}})
logins3 = logins3.replace({'Gmail Integration': {'Yes': 1, 
                                'No': 0}})
logins3 = logins3.replace({'Used Admin Panel': {'Yes': 1, 
                                'No': 0}})
logins3 = logins3.replace({'Has Issued Support Request': {'Yes': 1, 
                                'No': 0}})

logins3
# Out:
#             User Name Slack Integration    Most Used Page  Had Free Trial  \
# 1267  Charlie Hurrell                No  /tool/storyboard               1
# 341        Paul Krupp               Yes  /tool/storyboard               1
# 452     Brigid Watson                No  /tool/storyboard               1
# 578     George Palmer               Yes  /tool/storyboard               1
# 1202   Claudia Wilson                No  /tool/storyboard               1
# ...               ...               ...               ...             ...
# 1152     Jessica Arce                No      /tool/search               0
# 133   Kenneth Janssen                No      /tool/search               0
# 519    Roland Grimaud                No      /tool/search               0
# 670        Jose Smith                No      /tool/search               0
# 180         Len Queen                No            /login               0
#
#       User MRR  Weekly Logins Company Name           Industry   Company Size  \
# 1267        39             17         Visa         Technology          >$10B
# 341        169             17  Lucky Brand  Consumer Products  $100M - $500M
# 452         39             17       Siemon      Manufacturing  $100M - $500M
# 578         39             17       SpaceX         Technology     $1B - $10B
# 1202       169             17         Visa         Technology          >$10B
# ...        ...            ...          ...                ...            ...
# 1152        39              0     Veritext        Hospitality         <$100M
# 133        169              0     Hushmail         Technology  $100M - $500M
# 519        169              0       Siemon      Manufacturing  $100M - $500M
# 670        169              0   Stupp Bros      Manufacturing  $100M - $500M
# 180        169              0     Hushmail         Technology  $100M - $500M
#
#      Territory  Sales Call in Trial  Zendesk Integration  \
# 1267      West                    0                    1
# 341       West                    0                    0
# 452    Midwest                    0                    0
# 578       West                    0                    1
# 1202      West                    0                    1
# ...        ...                  ...                  ...
# 1152   Midwest                    0                    0
# 133       West                    1                    1
# 519    Midwest                    0                    1
# 670    Midwest                    1                    1
# 180       West                    0                    1
#
#       Salesforce Integration  Gmail Integration Most common referrer  \
# 1267                       1                  1     /mail.google.com
# 341                        0                  1           /slack.com
# 452                        1                  1           hotels.com
# 578                        0                  0               /quora
# 1202                       1                  1        /facebook.com
# ...                      ...                ...                  ...
# 1152                       0                  1           hotels.com
# 133                        0                  1             zoom.com
# 519                        1                  1     /tripadvisor.com
# 670                        0                  0     /tripadvisor.com
# 180                        0                  0     /tripadvisor.com
#
#        Most common IP  Sales Touches to Close  Used Admin Panel  \
# 1267  198.199.120.102                       6                 0
# 341    138.197.222.35                       4                 1
# 452    192.200.200.99                      14                 1
# 578     174.138.54.49                       9                 0
# 1202  198.199.120.102                       5                 1
# ...               ...                     ...               ...
# 1152    34.87.141.207                       5                 0
# 133      191.96.42.80                      12                 1
# 519       72.35.40.34                      11                 1
# 670   198.199.120.102                      13                 0
# 180    67.205.132.241                      14                 0
#
#       Has Issued Support Request
# 1267                           1
# 341                            0
# 452                            1
# 578                            0
# 1202                           0
# ...                          ...
# 1152                           1
# 133                            0
# 519                            0
# 670                            1
# 180                            0
#
# [1718 rows x 19 columns]

# %%
logins3.groupby('Weekly Logins').mean()
# Out:
#                Had Free Trial    User MRR  Sales Call in Trial  \
# Weekly Logins
# 0                    0.000000  233.888889             0.444444
# 1                    0.000000  187.333333             0.333333
# 2                    0.017391  164.304348             0.365217
# 3                    0.040650  248.349593             0.422764
# 4                    0.047431  197.379447             0.347826
# 5                    0.165323  232.306452             0.358871
# 6                    0.281915  224.425532             0.388298
# 7                    0.466667  194.916667             0.425000
# 8                    0.960784  151.352941             0.392157
# 9                    1.000000  226.600000             0.500000
# 10                   1.000000  229.000000             0.343750
# 11                   1.000000  279.980392             0.392157
# 12                   1.000000  215.382979             0.404255
# 13                   1.000000  168.500000             0.383333
# 14                   1.000000  190.935484             0.451613
# 15                   1.000000  166.500000             0.406250
# 16                   1.000000  197.500000             0.550000
# 17                   1.000000  104.000000             0.166667
#
#                Zendesk Integration  Salesforce Integration  Gmail Integration  \
# Weekly Logins
# 0                         0.533333                0.244444           0.466667
# 1                         0.466667                0.433333           0.550000
# 2                         0.478261                0.382609           0.600000
# 3                         0.536585                0.463415           0.552846
# 4                         0.537549                0.387352           0.561265
# 5                         0.504032                0.427419           0.580645
# 6                         0.632979                0.436170           0.521277
# 7                         0.483333                0.425000           0.533333
# 8                         0.549020                0.411765           0.529412
# 9                         0.520000                0.320000           0.600000
# 10                        0.609375                0.437500           0.531250
# 11                        0.529412                0.431373           0.490196
# 12                        0.468085                0.361702           0.553191
# 13                        0.633333                0.366667           0.500000
# 14                        0.532258                0.419355           0.532258
# 15                        0.531250                0.375000           0.531250
# 16                        0.500000                0.650000           0.450000
# 17                        0.666667                0.666667           0.666667
#
#                Sales Touches to Close  Used Admin Panel  \
# Weekly Logins
# 0                           10.533333          0.466667
# 1                           10.050000          0.450000
# 2                            9.834783          0.356522
# 3                            9.589431          0.365854
# 4                            9.873518          0.438735
# 5                            9.943548          0.451613
# 6                           10.117021          0.468085
# 7                           10.116667          0.475000
# 8                           10.196078          0.372549
# 9                           10.000000          0.400000
# 10                          10.234375          0.421875
# 11                          10.254902          0.352941
# 12                           9.531915          0.553191
# 13                           9.600000          0.333333
# 14                           9.774194          0.483871
# 15                          10.875000          0.281250
# 16                           9.600000          0.400000
# 17                           7.333333          0.500000
#
#                Has Issued Support Request
# Weekly Logins
# 0                                0.555556
# 1                                0.400000
# 2                                0.547826
# 3                                0.536585
# 4                                0.525692
# 5                                0.516129
# 6                                0.563830
# 7                                0.616667
# 8                                0.470588
# 9                                0.520000
# 10                               0.531250
# 11                               0.745098
# 12                               0.489362
# 13                               0.600000
# 14                               0.564516
# 15                               0.500000
# 16                               0.550000
# 17                               0.500000

# %% [markdown]
# This table further shows that having a free trial increases the likelihood that a person will have a high number weekly logins. For all other variables, there does not seem to be any impact on whether a person will have a high number of weekly logins or not.
